# %% [markdown]
# # HW 3 Martine Maggi

# %% [markdown]
# ### <font color='orange'> *The Function*
# <font color='orange'>
# $$ p(x) = 0.164\exp{\left(-\frac{(x-10)^4}{2\cdot 8^2}\right)} $$
# </font>

# %% [markdown]
# #### Part 1: Drawing 1000 samples via rejection sampling
#
# Graphing the function:

# %% [markdown]
# ![image.png](attachment:3b778afd-23d7-45fa-9b9c-3e95bdea9adf.png)

# %% [markdown]
# Drawing 1000 random samples from a uniform distribution and running it through rejection sampling.

# %% [markdown]
# ![image.png](attachment:521740bb-5510-413f-b3d3-e9153eb418b8.png)

# %% [markdown]
# ### Part 2: Using Importance Sampling to estimate $\langle x \rangle$

# %% [markdown]
# The mean of the samples drawn before was 9.856362304848506.
#
# The estimates mean from importance sampling was 9.974405889718792.
#
# it was about a ~1.2% difference between the two.

# %% [markdown]
# ### Part 3: Using Importance Sampling to estimate $x^2$

# %% [markdown]
# Using importance sampling, the estimated value of $x^2$ is 103.32280745800489

# %% [markdown]
# ### Part 4 Grad Student Special: Using Weights to get target distribution

# %% [markdown]
# This is a comparison between the weighted importance samples and the random samples that survived the rejection sampling compared to the target distribution.

# %% [markdown]
# ![image.png](attachment:ed9ec2b8-5fb2-4acc-bd7e-be638e3a4419.png)
