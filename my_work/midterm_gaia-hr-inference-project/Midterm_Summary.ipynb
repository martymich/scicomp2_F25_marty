# %% [markdown]
# # Midterm Summary - Martine Maggi

# %% [markdown]
# # Part I:
#
# ## Cruce Removal of WD's and Restriction of parallax
#
# ![Screenshot 2025-11-18 at 2.54.46 PM.png](attachment:68aa5197-b273-4c4c-9f3c-fb703c87efa1.png)

# %% [markdown]
# ## Construct and Discuss Numpyro Linear Model and Plot
#
#
#
# ![Screenshot 2025-11-18 at 2.55.54 PM.png](attachment:170a4451-cb59-4ccf-97d0-e3d9bb8dd87f.png)
#
#
# I chose normal priors and the posteriors are fairly normal as well so it seems that was a good choice for shape. The means of the priors and posteriors are all different. The posterior means are within the prior distributions which still makes them valid prior distributions.
#
# ![Screenshot 2025-11-18 at 2.56.08 PM.png](attachment:ecce1c6c-89a1-44eb-a0a1-02734ededf99.png)
#
#
# The fit is decent for mose main sequance stars. We have deviation at the tails for high and low mass stars which both curve up and away.

# %% [markdown]
# ## Construct and Discuss a Quadratic Model
#
# ![Screenshot 2025-11-18 at 2.58.22 PM.png](attachment:feb4f826-be81-4aa1-8308-584996b113d5.png)
#
# ![Screenshot 2025-11-18 at 2.58.33 PM.png](attachment:37750ff2-c2c8-42c7-8e70-50aa570e4eaa.png)
#
# My priors here were all centered at 0 with a scale of 100 so they had plenty of space for the mcmc to explore. If I constrained them more, it may have sped up computation time by a few seconds but that isn't much of a concern here since it is already fast. I would call these priors less weill informed and more *allowing*.
#
# ![Screenshot 2025-11-18 at 2.59.09 PM.png](attachment:2ed6dfe2-ab09-4593-ac16-9ee3977b17a6.png)
#
# The quadratic model reasonably accounts for the high and low mass ends with only some outliers along the giant branch.
#
# #### Predicitve Distribution for BP_RP = 6
#
# ![Screenshot 2025-11-18 at 3.00.13 PM.png](attachment:8a5ccf49-86a3-4537-b5fb-18d08704a278.png)

# %% [markdown]
# ## Construct and Discuss a Cubic Model
#
# ![Screenshot 2025-11-18 at 3.00.53 PM.png](attachment:e7616a2c-2b92-4e87-a6a8-a32ab6b82d01.png)
#
# ![Screenshot 2025-11-18 at 3.01.09 PM.png](attachment:1ed4c3dd-3d7b-490f-9c5b-54c562e27327.png)
#
# ![Screenshot 2025-11-18 at 3.01.18 PM.png](attachment:7e151bbc-ec28-4d2e-8979-08d85a651604.png)
#
# I don't think a cubic function fits better since we can see it does not account for the inward/quadratically turning tails as well, particularly onthe high mass end.

# %% [markdown]
# # Part II: Return of the Dwarfs
#
# ![Screenshot 2025-11-18 at 3.02.30 PM.png](attachment:33cc2f42-68f3-45ed-ac19-a8c5c4d7b1a4.png)
#
# ## Mixture Model
#
# ![Screenshot 2025-11-18 at 3.03.04 PM.png](attachment:c3a6afa9-b219-4f3d-b2f5-3def8a8bb508.png)
#
# The model is able to succesfully identify the two populations. A double quadratic model would fit both better since both have the similar deviations from the linear line.
#
# ## Distribution that each star is in MS
#
# ![Screenshot 2025-11-18 at 3.03.49 PM.png](attachment:6eacf866-7fb1-4235-a456-4796a88c7c38.png)
#
# Wow very bimodal. There is not much uncertainty of wether or not the star is in the main sequence or not. Let's test that by taking a look at the mean uncertainty.
#
# ![Screenshot 2025-11-18 at 3.04.11 PM.png](attachment:d9ab87a2-b883-4b0a-a54b-b85b82cad026.png)
#
# Absolutely tiny. That tracks.
#
# Let' see the bimodalness in action with a color map:
#
# ![Screenshot 2025-11-18 at 3.04.46 PM.png](attachment:3b7f20ca-086d-40c3-93fd-6e9c0970b862.png)

# %% [markdown]
# ## Relaxed Prior Mixture Model
#
# ![Screenshot 2025-11-18 at 3.05.58 PM.png](attachment:184c1e1c-d243-44c8-b905-cba34b6c4144.png)
#
# Because we relaxed the priors, the mcmc is exploring the whole space, MS and WD at the same time. The result is that we do not have any distinguishment between the line for the WD's and MS's.
#
# ![Screenshot 2025-11-18 at 3.06.42 PM.png](attachment:3139f9bf-4361-4c1a-aef9-a0ec0104346a.png)
#
# We can see that the mcmc *is* fitting for both WD's and MS stars. We an see that there are local maxima in the WD and MS regions however the mean of both the WD and MS line as at the same location. The chain for the WD paramaters are also exploring the MS space and vice versa. INTERESTINGLY, the first 50 samples if the WD chain are plotted in the MS region! Similarly for MS, the first 50 samples are on the WD's! It is not doing a good job of modelling either.
